# %% [markdown]
# <a href="https://colab.research.google.com/github/NVTruong473/titanic-mini-project/blob/main/titanic_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DỰ ÁN: Phân tích dữ liệu Titanic bằng Google Colab + GitHub**

# %% [markdown]
# # **PROJECT: Analyzing Titanic data using Google Colab + GitHub**

# %% [markdown]
# ## **Step 1 - CODE**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = sns.load_dataset("titanic")

# Xem 5 dòng đầu
print(df.head())

# Biểu đồ 1
sns.barplot(x="sex", y="survived", data=df)
plt.title("Survival Rate by Gender")
plt.show()

# Biểu đồ 2
sns.barplot(x="class", y="survived", data=df)
plt.title("Survival Rate by Class")
plt.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## **Step 2 - CREATE A PYTHON FILE**

# %%
# %%writefile titanic_analysis.py

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("titanic")

print(df.head())

sns.barplot(x="sex", y="survived", data=df)
plt.title("Survival Rate by Gender")
plt.show()

sns.barplot(x="class", y="survived", data=df)
plt.title("Survival Rate by Class")
plt.show()
# Out:
# Overwriting titanic_analysis.py

# %% [markdown]
# ## **Step 3 - CREATE README**

# %%
content = """
# Titanic Mini Project

Mini data analysis project using Python + Google Colab.

## Files
- titanic_analysis.py
- titanic_analysis.ipynb

## Result
- Survival Rate by Gender
- Survival Rate by Class

---

# Dự án Mini Titanic

Dự án phân tích dữ liệu nhỏ sử dụng Python + Google Colab.

## Tệp
- titanic_analysis.py
- titanic_analysis.ipynb

## Kết quả
- Tỷ lệ sống sót theo giới tính
- Tỷ lệ sống sót theo hạng vé
"""

with open("README.md","w") as f:
    f.write(content)

# %% [markdown]
# ## **Step 4 - GIT INIT**

# %%
# !git init
# !git config --global user.name "NVTruong473"
# !git config --global user.email "Truong040723@gmail.com"
# Out:
# Reinitialized existing Git repository in /content/.git/

# %% [markdown]
# ## **Step 5 - .gitignore**

# %%
with open(".gitignore","w") as f:
    f.write(".ipynb_checkpoints/\n")
    f.write("__pycache__/\n")
    f.write(".config/\n")
    f.write("sample_data/\n")

# %% [markdown]
# ## **Step 6 - COMMIT**

# %%
# !git add .
# !git commit -m "Titanic project"
# !git branch -M main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# ## **Step 7 - PUSH GITHUB**

# %%
from google.colab import userdata

token = userdata.get("GITHUB")

# !git remote remove origin
# !git remote add origin https://NVTruong473:{token}@github.com/NVTruong473/titanic-mini-project.git

# !git push -u origin main --force
# Out:
# Enumerating objects: 42, done.
# Counting objects: 100% (42/42), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (35/35), done.
# Writing objects: 100% (42/42), 8.42 MiB | 1.79 MiB/s, done.
# Total 42 (delta 10), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (10/10), done.
# To https://github.com/NVTruong473/titanic-mini-project.git
#  + d6f5c2c...0694322 main -> main (forced update)
# Branch 'main' set up to track remote branch 'main' from 'origin'.
